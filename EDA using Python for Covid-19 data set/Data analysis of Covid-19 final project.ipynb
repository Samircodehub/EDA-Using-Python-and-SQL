# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv(r"C:\Users\Samir\Downloads\covid_19_india.csv",parse_dates=["Date"],dayfirst=True)
df
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00 PM               Kerala                       1
# 1          2 2020-01-31  6:00 PM               Kerala                       1
# 2          3 2020-02-01  6:00 PM               Kerala                       2
# 3          4 2020-02-02  6:00 PM               Kerala                       3
# 4          5 2020-02-03  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106 2021-08-11  8:00 AM            Telangana                       -
# 18106  18107 2021-08-11  8:00 AM              Tripura                       -
# 18107  18108 2021-08-11  8:00 AM          Uttarakhand                       -
# 18108  18109 2021-08-11  8:00 AM        Uttar Pradesh                       -
# 18109  18110 2021-08-11  8:00 AM          West Bengal                       -
#
# ...

# %% [markdown]
# ## Removing unnecessary columns

# %%
df = df.drop(['ConfirmedIndianNational', 'ConfirmedForeignNational', 'Time'], axis = 1)
df.head()
# Out:
#    Sno       Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0    1 2020-01-30               Kerala      0       0          1
# 1    2 2020-01-31               Kerala      0       0          1
# 2    3 2020-02-01               Kerala      0       0          2
# 3    4 2020-02-02               Kerala      0       0          3
# 4    5 2020-02-03               Kerala      0       0          3

# %%
df = df.drop(['Sno'], axis = 1)
df.head()
# Out:
#         Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0 2020-01-30               Kerala      0       0          1
# 1 2020-01-31               Kerala      0       0          1
# 2 2020-02-01               Kerala      0       0          2
# 3 2020-02-02               Kerala      0       0          3
# 4 2020-02-03               Kerala      0       0          3

# %% [markdown]
# ## Reanaming 'State/UnionTerritory' to 'state'

# %%
df.rename(columns = {'State/UnionTerritory':'state'}, inplace = True)

# %%
df
# Out:
#             Date          state    Cured  Deaths  Confirmed
# 0     2020-01-30         Kerala        0       0          1
# 1     2020-01-31         Kerala        0       0          1
# 2     2020-02-01         Kerala        0       0          2
# 3     2020-02-02         Kerala        0       0          3
# 4     2020-02-03         Kerala        0       0          3
# ...          ...            ...      ...     ...        ...
# 18105 2021-08-11      Telangana   638410    3831     650353
# 18106 2021-08-11        Tripura    77811     773      80660
# 18107 2021-08-11    Uttarakhand   334650    7368     342462
# 18108 2021-08-11  Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11    West Bengal  1506532   18252    1534999
#
# [18110 rows x 5 columns]

# %% [markdown]
# ## Cheaking for null value

# %%
df.isnull().sum()
# Out:
# Date         0
# state        0
# Cured        0
# Deaths       0
# Confirmed    0
# dtype: int64

# %%
today=df[df.Date=="2021-08-11"]
today
# Out:
#             Date                                     state    Cured  Deaths  \
# 18074 2021-08-11               Andaman and Nicobar Islands     7412     129
# 18075 2021-08-11                            Andhra Pradesh  1952736   13564
# 18076 2021-08-11                         Arunachal Pradesh    47821     248
# 18077 2021-08-11                                     Assam   559684    5420
# 18078 2021-08-11                                     Bihar   715352    9646
# 18079 2021-08-11                                Chandigarh    61150     811
# 18080 2021-08-11                              Chhattisgarh   988189   13544
# 18081 2021-08-11  Dadra and Nagar Haveli and Daman and Diu    10646       4
# 18082 2021-08-11                                     Delhi  1411280   25068
# 18083 2021-08-11                                       Goa   167978    3164
# 18084 2021-08-11                                   Gujarat   814802   10077
# ...

# %%
#sorting data with respect to confirmed cases
max_confirmed_cases=today.sort_values(by="Confirmed",ascending=False)

# %%
max_confirmed_cases.head(10)
# Out:
#             Date           state    Cured  Deaths  Confirmed
# 18094 2021-08-11     Maharashtra  6159676  134201    6363442
# 18090 2021-08-11          Kerala  3396184   18004    3586693
# 18089 2021-08-11       Karnataka  2861499   36848    2921049
# 18104 2021-08-11      Tamil Nadu  2524400   34367    2579130
# 18075 2021-08-11  Andhra Pradesh  1952736   13564    1985182
# 18108 2021-08-11   Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11     West Bengal  1506532   18252    1534999
# 18082 2021-08-11           Delhi  1411280   25068    1436852
# 18080 2021-08-11    Chhattisgarh   988189   13544    1003356
# 18099 2021-08-11          Odisha   972710    6565     988997

# %%
# Extract top ten states with comfirmed
top_states_confirmed=max_confirmed_cases[0:10]
top_states_confirmed
# Out:
#             Date           state    Cured  Deaths  Confirmed
# 18094 2021-08-11     Maharashtra  6159676  134201    6363442
# 18090 2021-08-11          Kerala  3396184   18004    3586693
# 18089 2021-08-11       Karnataka  2861499   36848    2921049
# 18104 2021-08-11      Tamil Nadu  2524400   34367    2579130
# 18075 2021-08-11  Andhra Pradesh  1952736   13564    1985182
# 18108 2021-08-11   Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11     West Bengal  1506532   18252    1534999
# 18082 2021-08-11           Delhi  1411280   25068    1436852
# 18080 2021-08-11    Chhattisgarh   988189   13544    1003356
# 18099 2021-08-11          Odisha   972710    6565     988997

# %% [markdown]
# ## Visualizing number of confirmed cases with respect to states (Top 10 states)

# %%
sns.set(rc={"figure.figsize":[15,8]})
sns.barplot(x="state",y="Confirmed",data=top_states_confirmed,hue="state")
plt.show()

# %%
max_deaths_cases=today.sort_values(by="Deaths",ascending=False)
max_deaths_cases.head(10)
# Out:
#             Date           state    Cured  Deaths  Confirmed
# 18094 2021-08-11     Maharashtra  6159676  134201    6363442
# 18089 2021-08-11       Karnataka  2861499   36848    2921049
# 18104 2021-08-11      Tamil Nadu  2524400   34367    2579130
# 18082 2021-08-11           Delhi  1411280   25068    1436852
# 18108 2021-08-11   Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11     West Bengal  1506532   18252    1534999
# 18090 2021-08-11          Kerala  3396184   18004    3586693
# 18101 2021-08-11          Punjab   582791   16322     599573
# 18075 2021-08-11  Andhra Pradesh  1952736   13564    1985182
# 18080 2021-08-11    Chhattisgarh   988189   13544    1003356

# %%
top_states_deaths=max_deaths_cases[0:10]
top_states_deaths
# Out:
#             Date           state    Cured  Deaths  Confirmed
# 18094 2021-08-11     Maharashtra  6159676  134201    6363442
# 18089 2021-08-11       Karnataka  2861499   36848    2921049
# 18104 2021-08-11      Tamil Nadu  2524400   34367    2579130
# 18082 2021-08-11           Delhi  1411280   25068    1436852
# 18108 2021-08-11   Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11     West Bengal  1506532   18252    1534999
# 18090 2021-08-11          Kerala  3396184   18004    3586693
# 18101 2021-08-11          Punjab   582791   16322     599573
# 18075 2021-08-11  Andhra Pradesh  1952736   13564    1985182
# 18080 2021-08-11    Chhattisgarh   988189   13544    1003356

# %% [markdown]
# ## Visualizing number of deaths with respect to states (Top 10 states)

# %%
sns.set(rc={"figure.figsize":[15,8]})
sns.barplot(x="state",y="Deaths",data=top_states_deaths,hue="state")
plt.show()

# %%
max_cured_cases=today.sort_values(by="Cured",ascending=False)
max_cured_cases.head(10)
# Out:
#             Date           state    Cured  Deaths  Confirmed
# 18094 2021-08-11     Maharashtra  6159676  134201    6363442
# 18090 2021-08-11          Kerala  3396184   18004    3586693
# 18089 2021-08-11       Karnataka  2861499   36848    2921049
# 18104 2021-08-11      Tamil Nadu  2524400   34367    2579130
# 18075 2021-08-11  Andhra Pradesh  1952736   13564    1985182
# 18108 2021-08-11   Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11     West Bengal  1506532   18252    1534999
# 18082 2021-08-11           Delhi  1411280   25068    1436852
# 18080 2021-08-11    Chhattisgarh   988189   13544    1003356
# 18099 2021-08-11          Odisha   972710    6565     988997

# %%
top_states_cured=max_cured_cases[0:10]
top_states_cured
# Out:
#             Date           state    Cured  Deaths  Confirmed
# 18094 2021-08-11     Maharashtra  6159676  134201    6363442
# 18090 2021-08-11          Kerala  3396184   18004    3586693
# 18089 2021-08-11       Karnataka  2861499   36848    2921049
# 18104 2021-08-11      Tamil Nadu  2524400   34367    2579130
# 18075 2021-08-11  Andhra Pradesh  1952736   13564    1985182
# 18108 2021-08-11   Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11     West Bengal  1506532   18252    1534999
# 18082 2021-08-11           Delhi  1411280   25068    1436852
# 18080 2021-08-11    Chhattisgarh   988189   13544    1003356
# 18099 2021-08-11          Odisha   972710    6565     988997

# %% [markdown]
# ## Visualizing the number of cured cases with respect to state

# %%
sns.set(rc={"figure.figsize":[15,8]})
sns.barplot(x="state",y="Cured",data=top_states_cured,hue="state")
plt.show()

# %% [markdown]
# # Analysis for Maharastra state

# %%
maha=df[df.state=="Maharashtra"]
maha
# Out:
#             Date        state    Cured  Deaths  Confirmed
# 76    2020-03-09  Maharashtra        0       0          2
# 91    2020-03-10  Maharashtra        0       0          5
# 97    2020-03-11  Maharashtra        0       0          2
# 120   2020-03-12  Maharashtra        0       0         11
# 133   2020-03-13  Maharashtra        0       0         14
# ...          ...          ...      ...     ...        ...
# 17950 2021-08-07  Maharashtra  6130137  133717    6341759
# 17986 2021-08-08  Maharashtra  6139493  133845    6347820
# 18022 2021-08-09  Maharashtra  6144388  133996    6353328
# 18058 2021-08-10  Maharashtra  6151956  134064    6357833
# 18094 2021-08-11  Maharashtra  6159676  134201    6363442
#
# [520 rows x 5 columns]

# %%
maha.head()
# Out:
#           Date        state  Cured  Deaths  Confirmed
# 76  2020-03-09  Maharashtra      0       0          2
# 91  2020-03-10  Maharashtra      0       0          5
# 97  2020-03-11  Maharashtra      0       0          2
# 120 2020-03-12  Maharashtra      0       0         11
# 133 2020-03-13  Maharashtra      0       0         14

# %%
maha.tail()
# Out:
#             Date        state    Cured  Deaths  Confirmed
# 17950 2021-08-07  Maharashtra  6130137  133717    6341759
# 17986 2021-08-08  Maharashtra  6139493  133845    6347820
# 18022 2021-08-09  Maharashtra  6144388  133996    6353328
# 18058 2021-08-10  Maharashtra  6151956  134064    6357833
# 18094 2021-08-11  Maharashtra  6159676  134201    6363442

# %% [markdown]
# ## Visualizing confirmed cases trend with date in maharastra

# %%
sns.set(rc={"figure.figsize":(20,8)})
sns.lineplot(x="Date",y="Confirmed",data=maha,color="green")
plt.show()

# %% [markdown]
# ## Visualizing death cases trend with date in maharastra

# %%
sns.set(rc={"figure.figsize":(15,8)})
sns.lineplot(x="Date",y="Deaths",data=maha,color="red")
plt.show()

# %% [markdown]
# ## Visualizing Cured cases trend with date in maharastra

# %%
sns.set(rc={"figure.figsize":(15,8)})
sns.lineplot(x="Date",y="Cured",data=maha,color="red")
plt.show()

# %%
sns.set(rc={"figure.figsize":(15,8)})
sns.relplot(x="Date",y="Cured",data=maha,hue= 'Cured')
plt.title("No. of Cured Trend")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Questions and answers relates to dataset

# %% [markdown]
# ### Q.1) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
df.groupby('state').sum()
# Out:
#                                                Cured    Deaths   Confirmed
# state
# Andaman and Nicobar Islands                  1848286     27136     1938498
# Andhra Pradesh                             370426530   2939367   392432753
# Arunachal Pradesh                            6588149     26799     7176907
# Assam                                       92678680    638323    99837011
# Bihar                                      125122902   1093466   132231166
# Bihar****                                    1402468     18881     1430909
# Cases being reassigned to states                   0         0      345565
# Chandigarh                                  10117035    147694    10858627
# Chhattisgarh                               151609364   2063920   163776262
# Dadra and Nagar Haveli                         20352         8       20722
# Dadra and Nagar Haveli and Daman and Diu     1841750      1014     1938632
# ...

# %% [markdown]
# ### Q.2) In which Region, maximum number of Confirmed cases were recorded ?

# %%
df.groupby('state')['Confirmed'].sum().sort_values(ascending = False).head(5)
# Out:
# state
# Maharashtra       1121491467
# Karnataka          485970693
# Kerala             458906023
# Tamil Nadu         431928644
# Andhra Pradesh     392432753
# Name: Confirmed, dtype: int64

# %% [markdown]
# ### Q.3) In which Region, minimum number of Deaths cases were recorded ?

# %%
df.groupby('state')['Deaths'].sum().sort_values(ascending = True).head(10)
# Out:
# state
# Unassigned                                      0
# Cases being reassigned to states                0
# Daman & Diu                                     0
# Dadra and Nagar Haveli                          8
# Dadra and Nagar Haveli and Daman and Diu     1014
# Himanchal Pradesh                            3507
# Lakshadweep                                  3908
# Mizoram                                      9791
# Madhya Pradesh***                           10506
# Bihar****                                   18881
# Name: Deaths, dtype: int64
